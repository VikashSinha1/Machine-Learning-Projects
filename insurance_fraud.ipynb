# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('insurance_fraud')
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.drop('_c39',axis=1,inplace=True)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# changing the object dtype  into date time columns:

# %%
df['policy_date']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.day

# %%
df['policy_month']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.month

# %%
df['policy_year']=pd.to_datetime(df.policy_bind_date,format="%d-%m-%Y").dt.year

# %%
df['incident date']=pd.to_datetime(df.incident_date,format="%d-%m-%Y").dt.day

# %%
df['incident month']=pd.to_datetime(df.incident_date,format="%d-%m-%Y").dt.month

# %%
df['incident year']=pd.to_datetime(df.incident_date,format="%d-%m-%Y").dt.year

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.drop(['policy_bind_date',"incident_date"],axis=1,inplace=True)

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_state policy_csl  \
# 0                   328   48         521585           OH    250/500
# 1                   228   42         342868           IN    250/500
# 2                   134   29         687698           OH    100/300
# 3                   256   41         227811           IL    250/500
# 4                   228   44         367455           IL   500/1000
# ..                  ...  ...            ...          ...        ...
# 995                   3   38         941851           OH   500/1000
# 996                 285   41         186934           IL    100/300
# 997                 130   34         918516           OH    250/500
# 998                 458   62         533940           IL   500/1000
# 999                 456   60         556080           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='policy_state',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['auto_year'],kde=False)
# Out:
# <AxesSubplot:xlabel='auto_year'>

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='auto_year',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='count'>

# %%
plt.figure(figsize=(15,12))
sns.countplot(df['auto_make'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='auto_make',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='police_report_available',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['incident_type'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='incident_type',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['incident_severity'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['incident_city'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='count'>

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_state policy_csl  \
# 0                   328   48         521585           OH    250/500
# 1                   228   42         342868           IN    250/500
# 2                   134   29         687698           OH    100/300
# 3                   256   41         227811           IL    250/500
# 4                   228   44         367455           IL   500/1000
# ..                  ...  ...            ...          ...        ...
# 995                   3   38         941851           OH   500/1000
# 996                 285   41         186934           IL    100/300
# 997                 130   34         918516           OH    250/500
# 998                 458   62         533940           IL   500/1000
# 999                 456   60         556080           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
df['auto_model'].value_counts()
# Out:
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# E400              27
# 95                27
# F150              27
# Grand Cherokee    25
# 93                25
# Escape            24
# Maxima            24
# Tahoe             24
# X5                23
# Ultima            23
# Highlander        22
# Silverado         22
# Civic             22
# Fusion            21
# Corolla           20
# Impreza           20
# TL                20
# ML350             20
# CRV               20
# 3 Series          18
# C300              18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64

# %%
df['umbrella_limit'].unique
# Out:
# <bound method Series.unique of 0            0
# 1      5000000
# 2      5000000
# 3      6000000
# 4      6000000
#         ...
# 995          0
# 996          0
# 997    3000000
# 998    5000000
# 999          0
# Name: umbrella_limit, Length: 1000, dtype: int64>

# %% [markdown]
# lets remove the unnecessary columns which may hamper the accuracy of our model

# %%
df.drop(['insured_hobbies','insured_education_level','insured_relationship','incident_location'],axis=1,inplace=True)

# %% [markdown]
# lets convert the categorical features into numerical using ordinal encoder

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# here we can see that there is a huge percentage of corelation in
# 1=total_claim_ammount and vehichle claim
# 2=age and months as costumer
# 3=injuy_claim and total claim

# %%
df.drop(['age','vehicle_claim','injury_claim'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord=OrdinalEncoder()
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=ord.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      months_as_customer  policy_number  policy_state  policy_csl  \
# 0                   328         521585           2.0         1.0
# 1                   228         342868           1.0         1.0
# 2                   134         687698           2.0         0.0
# 3                   256         227811           0.0         1.0
# 4                   228         367455           0.0         2.0
# ..                  ...            ...           ...         ...
# 995                   3         941851           2.0         2.0
# 996                 285         186934           0.0         0.0
# 997                 130         918516           2.0         1.0
# 998                 458         533940           0.0         2.0
# 999                 456         556080           2.0         1.0
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# ...

# %%
plt.figure(figsize=(22,10))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar',color='c')
# Out:
# <AxesSubplot:>

# %% [markdown]
# lets check for skewness

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# policy_number                  0.038991
# policy_state                  -0.026177
# policy_csl                     0.088928
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# insured_sex                    0.148630
# insured_occupation            -0.058881
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.193345
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# property_damage                0.106418
# bodily_injuries                0.014777
# witnesses                      0.019636
# ...

# %%
for feature in df.columns:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,8))

# %% [markdown]
# lets fix the outliers using quantile function

# %%
IQR=df.policy_annual_premium.quantile(0.75)-df.policy_annual_premium.quantile(0.25)
lower_bridge=df.policy_annual_premium.quantile(0.25)-(IQR*1.5)
upper_bridge=df.policy_annual_premium.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 600.4762499999999 1904.8262500000003

# %%
df.loc[df['policy_annual_premium']>=1904.82,'policy_annual_premium']=1904.82
df.loc[df['policy_annual_premium']<=600.47,'policy_annual_premium']=600.47

# %%
IQR=df.umbrella_limit.quantile(0.75)-df.umbrella_limit.quantile(0.25)
lower_bridge=df.umbrella_limit.quantile(0.25)-(IQR*1.5)
upper_bridge=df.umbrella_limit.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 0.0 0.0

# %%
df.loc[df['umbrella_limit']>=0.0,'umbrella_limit']=0.0
df.loc[df['umbrella_limit']<=0.0,'umbrella_limit']=0.0

# %%
IQR=df.property_claim.quantile(0.75)-df.property_claim.quantile(0.25)
lower_bridge=df.property_claim.quantile(0.25)-(IQR*1.5)
upper_bridge=df.property_claim.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5215.0 20545.0

# %%
df.loc[df['property_claim']>=20545.0,'property_claim']=20545.0
df.loc[df['property_claim']<=-5215.0,'property_claim']=-5215.0

# %% [markdown]
# now lets check again

# %%
for feature in df.columns:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,8))

# %%
df
# Out:
#      months_as_customer  policy_number  policy_state  policy_csl  \
# 0                   328         521585           2.0         1.0
# 1                   228         342868           1.0         1.0
# 2                   134         687698           2.0         0.0
# 3                   256         227811           0.0         1.0
# 4                   228         367455           0.0         2.0
# ..                  ...            ...           ...         ...
# 995                   3         941851           2.0         2.0
# 996                 285         186934           0.0         0.0
# 997                 130         918516           2.0         1.0
# 998                 458         533940           0.0         2.0
# 999                 456         556080           2.0         1.0
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# ...

# %% [markdown]
# now lets do the scaling of the data using minmaxscaler

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
x=df.drop('fraud_reported',axis=1)
y=df['fraud_reported']

# %%
mm=MinMaxScaler()
x=mm.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.25)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.752
# [[171   9]
#  [ 53  17]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.95      0.85       180
#          1.0       0.65      0.24      0.35        70
#
#     accuracy                           0.75       250
#    macro avg       0.71      0.60      0.60       250
# weighted avg       0.73      0.75      0.71       250

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.724
# [[180   0]
#  [ 69   1]]
#               precision    recall  f1-score   support
#
#          0.0       0.72      1.00      0.84       180
#          1.0       1.00      0.01      0.03        70
#
#     accuracy                           0.72       250
#    macro avg       0.86      0.51      0.43       250
# weighted avg       0.80      0.72      0.61       250

# %% [markdown]
# here we can see that the precision recall as well as f1 score is not good for 1. lets check

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# here we can see that the output columns is inbalanced. lets balance it using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
sns.countplot(trainy)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
lr=LogisticRegression()
lr.fit(trainx,trainy)
lr.score(trainx,trainy)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.732
# [[131  49]
#  [ 18  52]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.73      0.80       180
#          1.0       0.51      0.74      0.61        70
#
#     accuracy                           0.73       250
#    macro avg       0.70      0.74      0.70       250
# weighted avg       0.78      0.73      0.74       250

# %%
svc=SVC()
svc.fit(trainx,trainy)
svc.score(trainx,trainy)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.908
# [[169  11]
#  [ 12  58]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.94      0.94       180
#          1.0       0.84      0.83      0.83        70
#
#     accuracy                           0.91       250
#    macro avg       0.89      0.88      0.89       250
# weighted avg       0.91      0.91      0.91       250

# %% [markdown]
# we can clearly see that for both 0 and 1 the precision rcall as well as f1 score has improved

# %% [markdown]
# lets check with some more algorithms

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(trainx,trainy)
dtc.score(trainx,trainy)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 1.0
# [[180   0]
#  [  0  70]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       180
#          1.0       1.00      1.00      1.00        70
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc=KNeighborsClassifier()
knc.fit(trainx,trainy)
knc.score(trainx,trainy)
predknc=knc.predict(x_test)
print(accuracy_score(y_test,predknc))
print(confusion_matrix(y_test,predknc))
print(classification_report(y_test,predknc))
# Out:
# 0.664
# [[98 82]
#  [ 2 68]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.54      0.70       180
#          1.0       0.45      0.97      0.62        70
#
#     accuracy                           0.66       250
#    macro avg       0.72      0.76      0.66       250
# weighted avg       0.83      0.66      0.68       250

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(trainx,trainy)
rf.score(trainx,trainy)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 1.0
# [[180   0]
#  [  0  70]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       180
#          1.0       1.00      1.00      1.00        70
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
xtc=ExtraTreesClassifier()
xtc.fit(trainx,trainy)
xtc.score(trainx,trainy)
predxtc=xtc.predict(x_test)
print(accuracy_score(y_test,predxtc))
print(confusion_matrix(y_test,predxtc))
print(classification_report(y_test,predxtc))
# Out:
# 1.0
# [[180   0]
#  [  0  70]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       180
#          1.0       1.00      1.00      1.00        70
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# lets take the above algorithms to check for cross validation

# %%
from sklearn.model_selection import cross_val_score
predsvc=svc.predict(x_test)
lss=accuracy_score(y_test,predsvc)
for j in range(2,10):
    lsscore=cross_val_score(svc,trainx,trainy,cv=j)
    lsc=lsscore.mean()
    print("at cv:",j)
    print("cross validation score is :",lsc*100)
    print("accuracy score is:",lss*100)
    print("\n")
# Out:
# at cv: 2
# cross validation score is : 82.66932270916334
# accuracy score is: 90.8
#
#
# at cv: 3
# cross validation score is : 82.53652058432935
# accuracy score is: 90.8
#
#
# at cv: 4
# cross validation score is : 84.40110192448785
# accuracy score is: 90.8
#
#
# at cv: 5
# cross validation score is : 84.66700402631405
# accuracy score is: 90.8
#
#
# at cv: 6
# cross validation score is : 84.4621513944223
# accuracy score is: 90.8
#
#
# at cv: 7
# cross validation score is : 85.33222591362126
# accuracy score is: 90.8
#
#
# at cv: 8
# cross validation score is : 85.40435382190702
# accuracy score is: 90.8
#
#
# at cv: 9
# cross validation score is : 84.94479295377499
# accuracy score is: 90.8

# %%
from sklearn.model_selection import cross_val_score
predrf=rf.predict(x_test)
lss=accuracy_score(y_test,predrf)
for j in range(2,10):
    lsscore=cross_val_score(rf,trainx,trainy,cv=j)
    lsc=lsscore.mean()
    print("at cv:",j)
    print("cross validation score is :",lsc*100)
    print("accuracy score is:",lss*100)
    print("\n")
# Out:
# at cv: 2
# cross validation score is : 85.65737051792827
# accuracy score is: 100.0
#
#
# at cv: 3
# cross validation score is : 85.3917662682603
# accuracy score is: 100.0
#
#
# at cv: 4
# cross validation score is : 86.66138749365088
# accuracy score is: 100.0
#
#
# at cv: 5
# cross validation score is : 87.12657587291808
# accuracy score is: 100.0
#
#
# at cv: 6
# cross validation score is : 86.98539176626826
# accuracy score is: 100.0
#
#
# at cv: 7
# cross validation score is : 87.19176818014027
# accuracy score is: 100.0
#
#
# at cv: 8
# cross validation score is : 87.66675109760216
# accuracy score is: 100.0
#
#
# at cv: 9
# cross validation score is : 87.80454963089693
# accuracy score is: 100.0

# %%
from sklearn.model_selection import cross_val_score
predxtc=svc.predict(x_test)
lss=accuracy_score(y_test,predxtc)
for j in range(2,10):
    lsscore=cross_val_score(xtc,trainx,trainy,cv=j)
    lsc=lsscore.mean()
    print("at cv:",j)
    print("cross validation score is :",lsc*100)
    print("accuracy score is:",lss*100)
    print("\n")
# Out:
# at cv: 2
# cross validation score is : 89.9734395750332
# accuracy score is: 90.8
#
#
# at cv: 3
# cross validation score is : 90.5710491367862
# accuracy score is: 90.8
#
#
# at cv: 4
# cross validation score is : 91.63715503132231
# accuracy score is: 90.8
#
#
# at cv: 5
# cross validation score is : 91.37026688081671
# accuracy score is: 90.8
#
#
# at cv: 6
# cross validation score is : 91.56706507304118
# accuracy score is: 90.8
#
#
# at cv: 7
# cross validation score is : 91.23846437799926
# accuracy score is: 90.8
#
#
# at cv: 8
# cross validation score is : 91.84115726668918
# accuracy score is: 90.8
#
#
# at cv: 9
# cross validation score is : 91.3138009694896
# accuracy score is: 90.8

# %%
score=cross_val_score(svc,trainx,trainy,cv=8)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.73544974 0.78306878 0.82978723 0.88297872 0.88297872 0.88829787
#  0.92021277 0.90957447]
# 0.8540435382190702
# 0.06123742154211951

# %%
score=cross_val_score(xtc,trainx,trainy,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.85761589 0.88039867 0.94019934 0.95016611 0.95348837]
# 0.9163736771468175
# 0.03958224206174006

# %% [markdown]
# lets take our final model as xtc as its giving best accuracy among other algorithms

# %% [markdown]
# lets do the hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators=[int(x) for x in np.linspace(start=10,stop=80,num=10)]
criterion=['gini','entropy']
max_features=['auto','sqrt']
max_depth=[2,4]
min_samples_split=[2,5]
min_samples_leaf=[1,2]
bootstrap=[True,False]

# %%
grid_param={"n_estimators": n_estimators,
            "criterion": criterion,
           'max_features': max_features,
           'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf,
            'bootstrap': bootstrap}

# %%
print(grid_param)
# Out:
# {'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72, 80], 'criterion': ['gini', 'entropy'], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 4], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
xt=ExtraTreesClassifier()
xt_grid=GridSearchCV(estimator=xt,param_grid=grid_param,cv=6,verbose=2,n_jobs=4)
xt_grid.fit(trainx,trainy)
# Out:
# Fitting 6 folds for each of 640 candidates, totalling 3840 fits
# GridSearchCV(cv=6, estimator=ExtraTreesClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'], 'max_depth': [2, 4],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72,
#                                           80]},
#              verbose=2)

# %%
print(xt_grid.best_params_)
# Out:
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 72}

# %%
pred=xt_grid.predict(x_test)

# %%
xt=ExtraTreesClassifier(bootstrap='False',criterion='entropy',max_depth=4,max_features='sqrt',min_samples_split=5,min_samples_leaf=2,n_estimators=48)
xt.fit(trainx,trainy)
xt.score(trainx,trainy)
predxt=xt.predict(x_test)
print(accuracy_score(y_test,predxt))
print(confusion_matrix(y_test,predxt))
print(classification_report(y_test,predxt))
# Out:
# 0.82
# [[156  24]
#  [ 21  49]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87       180
#          1.0       0.67      0.70      0.69        70
#
#     accuracy                           0.82       250
#    macro avg       0.78      0.78      0.78       250
# weighted avg       0.82      0.82      0.82       250

# %%
import pickle
filename='fraud_detection.pkl'
pickle.dump(xt,open(filename,'wb'))
